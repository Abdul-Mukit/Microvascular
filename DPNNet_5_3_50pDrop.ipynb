# %% [markdown]
# # Convolutional Neural Networks
# ---
# In this notebook, we train a **CNN** to classify spectrogram images of DPN+ and DPN- classes.

# %% [markdown]
# ### Test for [CUDA](http://pytorch.org/docs/stable/cuda.html)
#
# I have a 3000 core Nvdia Titan-X available in my workstation. Without GPU this code would take approximately 48 hours to complete. With GPU it takes about 45 minutes.
#
# Since these are larger (129x27x3) images, it will prove useful to speed up training time by using a GPU. CUDA is a parallel computing platform and CUDA Tensors are the same as typical Tensors, only they utilize GPU's for computation.

# %%
import torch
import numpy as np

# check if CUDA is available
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %% [markdown]
# ---
# ## Load the Data
#
# All spectrogram images are saved inside the 'data' foler. It has two subfolders, namely, "0" and "1". "0" folder contains images representing DPN- class while "1" foler represents DPN+ class.

# %%
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler

# %%
# number of subprocesses to use for data loading
num_workers = 0
# how many samples per batch to load
batch_size = 20

# %% [markdown]
# ### Define Transformations
# Before loading the training and testing data some transformations are done on them. For all of the training, validation and test datasets, follwoing transformations are done:
# * Resize 129x27 image to 128x32 images (for easier calculations of layer output)
# * All images are normalized to have 0.5 mean and 0.5 standard deviation.
# * Images are horizontally flipped with a probability of 0.5. This done to augment the dataset and strengthening the training, validation and testing.

# %%
# ### convert data to a normalized torch.FloatTensor
transforms = transforms.Compose([
    transforms.Resize((128, 32)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

# %% [markdown]
# ### Splitting Dataset
# Currently all images are inside the "data" folder. In the following section I split the image data into training, validation and testing groups maintaining a 70:15:15 proportion.

# %%
# choose the training and test datasets
# Loading datasets
data_dir = 'data'
trainPercent, valPercent, testPercent = 0.7, 0.15, 0.15 # has to equal to 1
all_data = datasets.ImageFolder(data_dir, transform=transforms)

# obtain training indices that will be used for validation
num_data = len(all_data)
indices = list(range(num_data))
np.random.shuffle(indices)

# Finding the splitting points
split1, split2 = int(np.floor(trainPercent * num_data)), int(np.floor((trainPercent+valPercent) * num_data))
train_idx, valid_idx, test_idx = indices[:split1], indices[split1:split2], indices[split2:]

# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)
test_sampler = SubsetRandomSampler(test_idx)

# prepare data loaders (combine dataset and sampler)
train_loader = torch.utils.data.DataLoader(all_data, batch_size=batch_size,
    sampler=train_sampler, num_workers=num_workers)

valid_loader = torch.utils.data.DataLoader(all_data, batch_size=batch_size, 
    sampler=valid_sampler, num_workers=num_workers)

test_loader = torch.utils.data.DataLoader(all_data, batch_size=batch_size, 
    sampler=test_sampler, num_workers=num_workers)

# %%
# specify the image classes
classes = ['DPN-', 'DPN+']

# %% [markdown]
# ### Visualize a Batch of Training Data

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# helper function to un-normalize and display an image
def imshow(img):
    img = img / 2 + 0.5  # unnormalize
    plt.imshow(np.transpose(img, (1, 2, 0)))  # convert from Tensor image

# %%
# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy() # convert images to numpy for display

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(25, 4))
# display 20 images
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])
    ax.set_title(classes[labels[idx]])

# %% [markdown]
# ### View an Image in More Detail
#
# Here, we look at the normalized red, green, and blue (RGB) color channels as three separate, grayscale intensity images.

# %%
rgb_img = np.squeeze(images[3])
channels = ['red channel', 'green channel', 'blue channel']

fig = plt.figure(figsize = (36, 36)) 
for idx in np.arange(rgb_img.shape[0]):
    ax = fig.add_subplot(1, 3, idx + 1)
    img = rgb_img[idx]
    ax.imshow(img, cmap='gray')
    ax.set_title(channels[idx])
    width, height = img.shape
    thresh = img.max()/2.5
    for x in range(width):
        for y in range(height):
            val = round(img[x][y],2) if img[x][y] !=0 else 0
            ax.annotate(str(val), xy=(y,x),
                    horizontalalignment='center',
                    verticalalignment='center', size=8,
                    color='white' if img[x][y]<thresh else 'black')

# %% [markdown]
# ---
# ## Defining the Network [Architecture](http://pytorch.org/docs/stable/nn.html)
#
#
# #### Output volume for a convolutional layer
# To compute the output size of a given convolutional layer we can perform the following calculation (taken from [Stanford's cs231n course](http://cs231n.github.io/convolutional-networks/#layers)):
# > We can compute the spatial size of the output volume as a function of the input volume size (W), the kernel/filter size (F), the stride with which they are applied (S), and the amount of zero padding used (P) on the border. The correct formula for calculating how many neurons define the output_W is given by `(W−F+2P)/S+1`.
#
# For example for a 7x7 input and a 3x3 filter with stride 1 and pad 0 we would get a 5x5 output. With stride 2 we would get a 3x3 output.

# %%
import torch.nn as nn
import torch.nn.functional as F

# define the CNN architecture
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        # convolutional layer (sees 128x32x3 image tensor)
        self.conv1 = nn.Conv2d(3, 16, 3, padding=1) 
        # convolutional layer (sees 64x16x16 tensor)
        self.conv2 = nn.Conv2d(16, 32, 3, padding=1) 
        # convolutional layer (sees 32x8x32 tensor)
        self.conv3 = nn.Conv2d(32, 64, 3, padding=1) 
        # convolutional layer (sees 16x4x64 tensor)
        self.conv4 = nn.Conv2d(64, 128, 3, padding=1)
        # convolutional layer (sees 8x2x128 tensor)
        self.conv5 = nn.Conv2d(128, 256, 3, padding=1)
        # output: 4*1*256
        
        
        # max pooling layer
        self.pool = nn.MaxPool2d(2, 2)
        # linear layer (4*1*256 -> 512)
        self.fc1 = nn.Linear(4*1*256, 512)
        # linear layer (512 -> 256)
        self.fc2 = nn.Linear(512, 256)
        # linear layer (256 -> 2)
        self.fc3 = nn.Linear(256, 2)
        # dropout layer (p=0.5)
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        # add sequence of convolutional and max pooling layers
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        x = self.pool(F.relu(self.conv4(x)))
        x = self.pool(F.relu(self.conv5(x)))
        # flatten image input
        x = x.view(-1, 4*1*256)
        # add dropout layer
        x = self.dropout(x)
        # add 1st hidden layer, with relu activation function
        x = F.relu(self.fc1(x))
        # add dropout layer
        x = self.dropout(x)
        # add 2nd hidden layer, with relu activation function
        x = F.relu(self.fc2(x))
        # add dropout layer
        x = self.dropout(x)
        # add 3nd hidden layer without relu
        x = self.fc3(x)
        
        return x

# create a complete CNN
model = Net()
print(model)

# move tensors to GPU if CUDA is available
if train_on_gpu:
    model.cuda()
# Out:
# Net(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv5): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=1024, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=2, bias=True)
#   (dropout): Dropout(p=0.5)
# )

# %% [markdown]
# ### Specify [Loss Function](http://pytorch.org/docs/stable/nn.html#loss-functions) and [Optimizer](http://pytorch.org/docs/stable/optim.html)
#
# I chose Cross-Entropy Loss as loss function and Stochastic Gradient Descent as my optimizer for this problem.
# I set the learning rate to 0.01.

# %%
import torch.optim as optim

# specify loss function (categorical cross-entropy)
criterion = nn.CrossEntropyLoss()

# specify optimizer
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %% [markdown]
# ---
# ## Train the Network
#
# Training the model with 300 epochs.
# While training the model weights will be saved whenever the validation loss decreases. In this way, after the training is done, we will have the best model saved.

# %%
# number of epochs to train the model
n_epochs = 300 # you may increase this number to train a final model

valid_loss_min = np.Inf # track change in validation loss

for epoch in range(1, n_epochs+1):

    # keep track of training and validation loss
    train_loss = 0.0
    valid_loss = 0.0
    
    ###################
    # train the model #
    ###################
    model.train()
    for data, target in train_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update training loss
        train_loss += loss.item()*data.size(0)
        
    ######################    
    # validate the model #
    ######################
    model.eval()
    for data, target in valid_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # update average validation loss 
        valid_loss += loss.item()*data.size(0)
    
    # calculate average losses
    train_loss = train_loss/len(train_loader.dataset)
    valid_loss = valid_loss/len(valid_loader.dataset)
        
    # print training/validation statistics 
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch, train_loss, valid_loss))
    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(model.state_dict(), 'model_cifar.pt')
        valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 0.484746 	Validation Loss: 0.103585
# Validation loss decreased (inf --> 0.103585).  Saving model ...
# Epoch: 2 	Training Loss: 0.484641 	Validation Loss: 0.103648
# Epoch: 3 	Training Loss: 0.484711 	Validation Loss: 0.103687
# Epoch: 4 	Training Loss: 0.484671 	Validation Loss: 0.103624
# Epoch: 5 	Training Loss: 0.484798 	Validation Loss: 0.103656
# Epoch: 6 	Training Loss: 0.484701 	Validation Loss: 0.103713
# Epoch: 7 	Training Loss: 0.484741 	Validation Loss: 0.103633
# Epoch: 8 	Training Loss: 0.484733 	Validation Loss: 0.103618
# Epoch: 9 	Training Loss: 0.484726 	Validation Loss: 0.103569
# Validation loss decreased (0.103585 --> 0.103569).  Saving model ...
# Epoch: 10 	Training Loss: 0.484775 	Validation Loss: 0.103636
# Epoch: 11 	Training Loss: 0.484764 	Validation Loss: 0.103564
# Validation loss decreased (0.103569 --> 0.103564).  Saving model ...
# Epoch: 12 	Training Loss: 0.484735 	Validation Loss: 0.103664
# Epoch: 13 	Training Loss: 0.484704 	Validation Loss: 0.103645
# Epoch: 14 	Training Loss: 0.484724 	Validation Loss: 0.103641
# Epoch: 15 	Training Loss: 0.484617 	Validation Loss: 0.103656
# Epoch: 16 	Training Loss: 0.484773 	Validation Loss: 0.103607
# Epoch: 17 	Training Loss: 0.484689 	Validation Loss: 0.103671
# Epoch: 18 	Training Loss: 0.484750 	Validation Loss: 0.103661
# Epoch: 19 	Training Loss: 0.484719 	Validation Loss: 0.103568
# Epoch: 20 	Training Loss: 0.484712 	Validation Loss: 0.103679
# Epoch: 21 	Training Loss: 0.484730 	Validation Loss: 0.103621
# Epoch: 22 	Training Loss: 0.484792 	Validation Loss: 0.103738
# Epoch: 23 	Training Loss: 0.484664 	Validation Loss: 0.103646
# Epoch: 24 	Training Loss: 0.484692 	Validation Loss: 0.103650
# Epoch: 25 	Training Loss: 0.484685 	Validation Loss: 0.103680
# Epoch: 26 	Training Loss: 0.484672 	Validation Loss: 0.103645
# Epoch: 27 	Training Loss: 0.484675 	Validation Loss: 0.103601
# Epoch: 28 	Training Loss: 0.484690 	Validation Loss: 0.103549
# Validation loss decreased (0.103564 --> 0.103549).  Saving model ...
# Epoch: 29 	Training Loss: 0.484632 	Validation Loss: 0.103725
# Epoch: 30 	Training Loss: 0.484747 	Validation Loss: 0.103588
# Epoch: 31 	Training Loss: 0.484640 	Validation Loss: 0.103534
# Validation loss decreased (0.103549 --> 0.103534).  Saving model ...
# Epoch: 32 	Training Loss: 0.484712 	Validation Loss: 0.103723
# Epoch: 33 	Training Loss: 0.484688 	Validation Loss: 0.103577
# Epoch: 34 	Training Loss: 0.484684 	Validation Loss: 0.103619
# Epoch: 35 	Training Loss: 0.484636 	Validation Loss: 0.103691
# Epoch: 36 	Training Loss: 0.484557 	Validation Loss: 0.103572
# Epoch: 37 	Training Loss: 0.484543 	Validation Loss: 0.103670
# Epoch: 38 	Training Loss: 0.484480 	Validation Loss: 0.103621
# Epoch: 39 	Training Loss: 0.484506 	Validation Loss: 0.103481
# Validation loss decreased (0.103534 --> 0.103481).  Saving model ...
# Epoch: 40 	Training Loss: 0.484426 	Validation Loss: 0.103503
# Epoch: 41 	Training Loss: 0.484444 	Validation Loss: 0.103583
# Epoch: 42 	Training Loss: 0.484377 	Validation Loss: 0.103522
# Epoch: 43 	Training Loss: 0.484355 	Validation Loss: 0.103550
# Epoch: 44 	Training Loss: 0.484166 	Validation Loss: 0.103387
# Validation loss decreased (0.103481 --> 0.103387).  Saving model ...
# Epoch: 45 	Training Loss: 0.483997 	Validation Loss: 0.103306
# Validation loss decreased (0.103387 --> 0.103306).  Saving model ...
# Epoch: 46 	Training Loss: 0.483846 	Validation Loss: 0.103446
# Epoch: 47 	Training Loss: 0.483591 	Validation Loss: 0.103197
# Validation loss decreased (0.103306 --> 0.103197).  Saving model ...
# Epoch: 48 	Training Loss: 0.483350 	Validation Loss: 0.102956
# Validation loss decreased (0.103197 --> 0.102956).  Saving model ...
# Epoch: 49 	Training Loss: 0.483034 	Validation Loss: 0.103022
# Epoch: 50 	Training Loss: 0.482417 	Validation Loss: 0.102620
# Validation loss decreased (0.102956 --> 0.102620).  Saving model ...
# Epoch: 51 	Training Loss: 0.481826 	Validation Loss: 0.102391
# Validation loss decreased (0.102620 --> 0.102391).  Saving model ...
# Epoch: 52 	Training Loss: 0.481862 	Validation Loss: 0.102343
# Validation loss decreased (0.102391 --> 0.102343).  Saving model ...
# Epoch: 53 	Training Loss: 0.481223 	Validation Loss: 0.102431
# Epoch: 54 	Training Loss: 0.480631 	Validation Loss: 0.102494
# Epoch: 55 	Training Loss: 0.480119 	Validation Loss: 0.102227
# Validation loss decreased (0.102343 --> 0.102227).  Saving model ...
# Epoch: 56 	Training Loss: 0.479387 	Validation Loss: 0.101923
# Validation loss decreased (0.102227 --> 0.101923).  Saving model ...
# Epoch: 57 	Training Loss: 0.479692 	Validation Loss: 0.101539
# Validation loss decreased (0.101923 --> 0.101539).  Saving model ...
# Epoch: 58 	Training Loss: 0.479193 	Validation Loss: 0.101427
# Validation loss decreased (0.101539 --> 0.101427).  Saving model ...
# Epoch: 59 	Training Loss: 0.478342 	Validation Loss: 0.101502
# Epoch: 60 	Training Loss: 0.478272 	Validation Loss: 0.101238
# Validation loss decreased (0.101427 --> 0.101238).  Saving model ...
# Epoch: 61 	Training Loss: 0.476626 	Validation Loss: 0.100948
# Validation loss decreased (0.101238 --> 0.100948).  Saving model ...
# Epoch: 62 	Training Loss: 0.476284 	Validation Loss: 0.101241
# Epoch: 63 	Training Loss: 0.474603 	Validation Loss: 0.100470
# Validation loss decreased (0.100948 --> 0.100470).  Saving model ...
# Epoch: 64 	Training Loss: 0.473174 	Validation Loss: 0.099915
# Validation loss decreased (0.100470 --> 0.099915).  Saving model ...
# Epoch: 65 	Training Loss: 0.471820 	Validation Loss: 0.099685
# Validation loss decreased (0.099915 --> 0.099685).  Saving model ...
# Epoch: 66 	Training Loss: 0.469447 	Validation Loss: 0.099126
# Validation loss decreased (0.099685 --> 0.099126).  Saving model ...
# Epoch: 67 	Training Loss: 0.469047 	Validation Loss: 0.102390
# Epoch: 68 	Training Loss: 0.467894 	Validation Loss: 0.098921
# Validation loss decreased (0.099126 --> 0.098921).  Saving model ...
# Epoch: 69 	Training Loss: 0.467715 	Validation Loss: 0.101330
# Epoch: 70 	Training Loss: 0.465402 	Validation Loss: 0.098897
# Validation loss decreased (0.098921 --> 0.098897).  Saving model ...
# Epoch: 71 	Training Loss: 0.465054 	Validation Loss: 0.097891
# Validation loss decreased (0.098897 --> 0.097891).  Saving model ...
# Epoch: 72 	Training Loss: 0.462774 	Validation Loss: 0.098151
# Epoch: 73 	Training Loss: 0.462912 	Validation Loss: 0.098273
# Epoch: 74 	Training Loss: 0.460162 	Validation Loss: 0.097408
# Validation loss decreased (0.097891 --> 0.097408).  Saving model ...
# Epoch: 75 	Training Loss: 0.458945 	Validation Loss: 0.097411
# Epoch: 76 	Training Loss: 0.457067 	Validation Loss: 0.096190
# Validation loss decreased (0.097408 --> 0.096190).  Saving model ...
# Epoch: 77 	Training Loss: 0.454929 	Validation Loss: 0.097397
# Epoch: 78 	Training Loss: 0.453303 	Validation Loss: 0.095128
# Validation loss decreased (0.096190 --> 0.095128).  Saving model ...
# Epoch: 79 	Training Loss: 0.451594 	Validation Loss: 0.096238
# Epoch: 80 	Training Loss: 0.450171 	Validation Loss: 0.094834
# Validation loss decreased (0.095128 --> 0.094834).  Saving model ...
# Epoch: 81 	Training Loss: 0.448087 	Validation Loss: 0.096430
# Epoch: 82 	Training Loss: 0.447001 	Validation Loss: 0.094031
# Validation loss decreased (0.094834 --> 0.094031).  Saving model ...
# Epoch: 83 	Training Loss: 0.445737 	Validation Loss: 0.095858
# Epoch: 84 	Training Loss: 0.442642 	Validation Loss: 0.094106
# Epoch: 85 	Training Loss: 0.440448 	Validation Loss: 0.095170
# Epoch: 86 	Training Loss: 0.438747 	Validation Loss: 0.096065
# Epoch: 87 	Training Loss: 0.436251 	Validation Loss: 0.091444
# Validation loss decreased (0.094031 --> 0.091444).  Saving model ...
# Epoch: 88 	Training Loss: 0.434667 	Validation Loss: 0.090454
# Validation loss decreased (0.091444 --> 0.090454).  Saving model ...
# Epoch: 89 	Training Loss: 0.432606 	Validation Loss: 0.090001
# Validation loss decreased (0.090454 --> 0.090001).  Saving model ...
# Epoch: 90 	Training Loss: 0.428665 	Validation Loss: 0.089879
# Validation loss decreased (0.090001 --> 0.089879).  Saving model ...
# Epoch: 91 	Training Loss: 0.425070 	Validation Loss: 0.088776
# Validation loss decreased (0.089879 --> 0.088776).  Saving model ...
# Epoch: 92 	Training Loss: 0.422768 	Validation Loss: 0.089712
# Epoch: 93 	Training Loss: 0.421733 	Validation Loss: 0.088971
# Epoch: 94 	Training Loss: 0.418130 	Validation Loss: 0.101853
# Epoch: 95 	Training Loss: 0.415555 	Validation Loss: 0.087468
# Validation loss decreased (0.088776 --> 0.087468).  Saving model ...
# Epoch: 96 	Training Loss: 0.414865 	Validation Loss: 0.086784
# Validation loss decreased (0.087468 --> 0.086784).  Saving model ...
# Epoch: 97 	Training Loss: 0.410140 	Validation Loss: 0.085401
# Validation loss decreased (0.086784 --> 0.085401).  Saving model ...
# Epoch: 98 	Training Loss: 0.408178 	Validation Loss: 0.087823
# Epoch: 99 	Training Loss: 0.405323 	Validation Loss: 0.086430
# Epoch: 100 	Training Loss: 0.402725 	Validation Loss: 0.085195
# Validation loss decreased (0.085401 --> 0.085195).  Saving model ...
# Epoch: 101 	Training Loss: 0.399683 	Validation Loss: 0.083431
# Validation loss decreased (0.085195 --> 0.083431).  Saving model ...
# Epoch: 102 	Training Loss: 0.397912 	Validation Loss: 0.082241
# Validation loss decreased (0.083431 --> 0.082241).  Saving model ...
# Epoch: 103 	Training Loss: 0.392951 	Validation Loss: 0.084271
# Epoch: 104 	Training Loss: 0.389861 	Validation Loss: 0.083320
# Epoch: 105 	Training Loss: 0.389317 	Validation Loss: 0.082508
# Epoch: 106 	Training Loss: 0.384263 	Validation Loss: 0.081149
# Validation loss decreased (0.082241 --> 0.081149).  Saving model ...
# Epoch: 107 	Training Loss: 0.380917 	Validation Loss: 0.081811
# Epoch: 108 	Training Loss: 0.380671 	Validation Loss: 0.081505
# Epoch: 109 	Training Loss: 0.374492 	Validation Loss: 0.085606
# Epoch: 110 	Training Loss: 0.373694 	Validation Loss: 0.079137
# Validation loss decreased (0.081149 --> 0.079137).  Saving model ...
# Epoch: 111 	Training Loss: 0.370726 	Validation Loss: 0.076862
# Validation loss decreased (0.079137 --> 0.076862).  Saving model ...
# Epoch: 112 	Training Loss: 0.367588 	Validation Loss: 0.083300
# Epoch: 113 	Training Loss: 0.364044 	Validation Loss: 0.076950
# Epoch: 114 	Training Loss: 0.361316 	Validation Loss: 0.075079
# Validation loss decreased (0.076862 --> 0.075079).  Saving model ...
# Epoch: 115 	Training Loss: 0.358645 	Validation Loss: 0.090356
# Epoch: 116 	Training Loss: 0.354918 	Validation Loss: 0.074461
# Validation loss decreased (0.075079 --> 0.074461).  Saving model ...
# Epoch: 117 	Training Loss: 0.352015 	Validation Loss: 0.079448
# Epoch: 118 	Training Loss: 0.349835 	Validation Loss: 0.073419
# Validation loss decreased (0.074461 --> 0.073419).  Saving model ...
# Epoch: 119 	Training Loss: 0.345736 	Validation Loss: 0.071334
# Validation loss decreased (0.073419 --> 0.071334).  Saving model ...
# Epoch: 120 	Training Loss: 0.340973 	Validation Loss: 0.071817
# Epoch: 121 	Training Loss: 0.339735 	Validation Loss: 0.070318
# Validation loss decreased (0.071334 --> 0.070318).  Saving model ...
# Epoch: 122 	Training Loss: 0.333995 	Validation Loss: 0.073182
# Epoch: 123 	Training Loss: 0.334154 	Validation Loss: 0.070526
# Epoch: 124 	Training Loss: 0.327674 	Validation Loss: 0.069075
# Validation loss decreased (0.070318 --> 0.069075).  Saving model ...
# Epoch: 125 	Training Loss: 0.324595 	Validation Loss: 0.068890
# Validation loss decreased (0.069075 --> 0.068890).  Saving model ...
# Epoch: 126 	Training Loss: 0.321778 	Validation Loss: 0.066197
# Validation loss decreased (0.068890 --> 0.066197).  Saving model ...
# Epoch: 127 	Training Loss: 0.318627 	Validation Loss: 0.070589
# Epoch: 128 	Training Loss: 0.316917 	Validation Loss: 0.064397
# Validation loss decreased (0.066197 --> 0.064397).  Saving model ...
# Epoch: 129 	Training Loss: 0.311720 	Validation Loss: 0.078150
# Epoch: 130 	Training Loss: 0.306296 	Validation Loss: 0.064496
# Epoch: 131 	Training Loss: 0.303178 	Validation Loss: 0.065671
# Epoch: 132 	Training Loss: 0.299806 	Validation Loss: 0.060793
# Validation loss decreased (0.064397 --> 0.060793).  Saving model ...
# Epoch: 133 	Training Loss: 0.295137 	Validation Loss: 0.059501
# Validation loss decreased (0.060793 --> 0.059501).  Saving model ...
# Epoch: 134 	Training Loss: 0.296430 	Validation Loss: 0.063039
# Epoch: 135 	Training Loss: 0.290407 	Validation Loss: 0.060038
# Epoch: 136 	Training Loss: 0.285764 	Validation Loss: 0.058047
# Validation loss decreased (0.059501 --> 0.058047).  Saving model ...
# Epoch: 137 	Training Loss: 0.282368 	Validation Loss: 0.062096
# Epoch: 138 	Training Loss: 0.277369 	Validation Loss: 0.058390
# Epoch: 139 	Training Loss: 0.276046 	Validation Loss: 0.061556
# Epoch: 140 	Training Loss: 0.272891 	Validation Loss: 0.057227
# Validation loss decreased (0.058047 --> 0.057227).  Saving model ...
# Epoch: 141 	Training Loss: 0.267962 	Validation Loss: 0.054456
# Validation loss decreased (0.057227 --> 0.054456).  Saving model ...
# Epoch: 142 	Training Loss: 0.265969 	Validation Loss: 0.088398
# Epoch: 143 	Training Loss: 0.262604 	Validation Loss: 0.053761
# Validation loss decreased (0.054456 --> 0.053761).  Saving model ...
# Epoch: 144 	Training Loss: 0.260672 	Validation Loss: 0.058398
# Epoch: 145 	Training Loss: 0.254119 	Validation Loss: 0.057422
# Epoch: 146 	Training Loss: 0.254839 	Validation Loss: 0.051011
# Validation loss decreased (0.053761 --> 0.051011).  Saving model ...
# Epoch: 147 	Training Loss: 0.251481 	Validation Loss: 0.052360
# Epoch: 148 	Training Loss: 0.246714 	Validation Loss: 0.049912
# Validation loss decreased (0.051011 --> 0.049912).  Saving model ...
# Epoch: 149 	Training Loss: 0.245052 	Validation Loss: 0.052198
# Epoch: 150 	Training Loss: 0.240493 	Validation Loss: 0.048232
# Validation loss decreased (0.049912 --> 0.048232).  Saving model ...
# Epoch: 151 	Training Loss: 0.238846 	Validation Loss: 0.051930
# Epoch: 152 	Training Loss: 0.238924 	Validation Loss: 0.051156
# Epoch: 153 	Training Loss: 0.231102 	Validation Loss: 0.050166
# Epoch: 154 	Training Loss: 0.230633 	Validation Loss: 0.049507
# Epoch: 155 	Training Loss: 0.231155 	Validation Loss: 0.052932
# Epoch: 156 	Training Loss: 0.226604 	Validation Loss: 0.051358
# Epoch: 157 	Training Loss: 0.223103 	Validation Loss: 0.045178
# Validation loss decreased (0.048232 --> 0.045178).  Saving model ...
# Epoch: 158 	Training Loss: 0.221189 	Validation Loss: 0.050577
# Epoch: 159 	Training Loss: 0.219612 	Validation Loss: 0.047959
# Epoch: 160 	Training Loss: 0.218469 	Validation Loss: 0.045383
# Epoch: 161 	Training Loss: 0.216194 	Validation Loss: 0.046615
# Epoch: 162 	Training Loss: 0.212027 	Validation Loss: 0.044875
# Validation loss decreased (0.045178 --> 0.044875).  Saving model ...
# Epoch: 163 	Training Loss: 0.207371 	Validation Loss: 0.045406
# Epoch: 164 	Training Loss: 0.211623 	Validation Loss: 0.045991
# Epoch: 165 	Training Loss: 0.206527 	Validation Loss: 0.049769
# Epoch: 166 	Training Loss: 0.202466 	Validation Loss: 0.043773
# Validation loss decreased (0.044875 --> 0.043773).  Saving model ...
# Epoch: 167 	Training Loss: 0.201735 	Validation Loss: 0.044917
# Epoch: 168 	Training Loss: 0.199406 	Validation Loss: 0.051566
# Epoch: 169 	Training Loss: 0.198261 	Validation Loss: 0.046961
# Epoch: 170 	Training Loss: 0.193625 	Validation Loss: 0.042753
# Validation loss decreased (0.043773 --> 0.042753).  Saving model ...
# Epoch: 171 	Training Loss: 0.194415 	Validation Loss: 0.041978
# Validation loss decreased (0.042753 --> 0.041978).  Saving model ...
# Epoch: 172 	Training Loss: 0.192557 	Validation Loss: 0.041472
# Validation loss decreased (0.041978 --> 0.041472).  Saving model ...
# Epoch: 173 	Training Loss: 0.187248 	Validation Loss: 0.047487
# Epoch: 174 	Training Loss: 0.185614 	Validation Loss: 0.043877
# Epoch: 175 	Training Loss: 0.183834 	Validation Loss: 0.041403
# Validation loss decreased (0.041472 --> 0.041403).  Saving model ...
# Epoch: 176 	Training Loss: 0.185638 	Validation Loss: 0.045611
# Epoch: 177 	Training Loss: 0.178753 	Validation Loss: 0.044405
# Epoch: 178 	Training Loss: 0.181913 	Validation Loss: 0.040475
# Validation loss decreased (0.041403 --> 0.040475).  Saving model ...
# Epoch: 179 	Training Loss: 0.178713 	Validation Loss: 0.043885
# Epoch: 180 	Training Loss: 0.174499 	Validation Loss: 0.044890
# Epoch: 181 	Training Loss: 0.170858 	Validation Loss: 0.040773
# Epoch: 182 	Training Loss: 0.172779 	Validation Loss: 0.039652
# Validation loss decreased (0.040475 --> 0.039652).  Saving model ...
# Epoch: 183 	Training Loss: 0.169753 	Validation Loss: 0.046212
# Epoch: 184 	Training Loss: 0.166431 	Validation Loss: 0.038543
# Validation loss decreased (0.039652 --> 0.038543).  Saving model ...
# Epoch: 185 	Training Loss: 0.168129 	Validation Loss: 0.040883
# Epoch: 186 	Training Loss: 0.163493 	Validation Loss: 0.039476
# Epoch: 187 	Training Loss: 0.165932 	Validation Loss: 0.044304
# Epoch: 188 	Training Loss: 0.166039 	Validation Loss: 0.043666
# Epoch: 189 	Training Loss: 0.156181 	Validation Loss: 0.042801
# Epoch: 190 	Training Loss: 0.160189 	Validation Loss: 0.039198
# Epoch: 191 	Training Loss: 0.157470 	Validation Loss: 0.038260
# Validation loss decreased (0.038543 --> 0.038260).  Saving model ...
# Epoch: 192 	Training Loss: 0.153146 	Validation Loss: 0.039849
# Epoch: 193 	Training Loss: 0.152284 	Validation Loss: 0.038461
# Epoch: 194 	Training Loss: 0.150687 	Validation Loss: 0.039953
# Epoch: 195 	Training Loss: 0.150409 	Validation Loss: 0.039623
# Epoch: 196 	Training Loss: 0.148417 	Validation Loss: 0.043349
# Epoch: 197 	Training Loss: 0.146813 	Validation Loss: 0.042332
# Epoch: 198 	Training Loss: 0.146480 	Validation Loss: 0.044657
# Epoch: 199 	Training Loss: 0.141186 	Validation Loss: 0.039736
# Epoch: 200 	Training Loss: 0.139720 	Validation Loss: 0.037192
# Validation loss decreased (0.038260 --> 0.037192).  Saving model ...
# Epoch: 201 	Training Loss: 0.141542 	Validation Loss: 0.041014
# Epoch: 202 	Training Loss: 0.137994 	Validation Loss: 0.038860
# Epoch: 203 	Training Loss: 0.139354 	Validation Loss: 0.036304
# Validation loss decreased (0.037192 --> 0.036304).  Saving model ...
# Epoch: 204 	Training Loss: 0.133889 	Validation Loss: 0.039285
# Epoch: 205 	Training Loss: 0.132973 	Validation Loss: 0.037316
# Epoch: 206 	Training Loss: 0.132937 	Validation Loss: 0.037346
# Epoch: 207 	Training Loss: 0.130810 	Validation Loss: 0.041051
# Epoch: 208 	Training Loss: 0.130432 	Validation Loss: 0.044731
# Epoch: 209 	Training Loss: 0.129374 	Validation Loss: 0.039588
# Epoch: 210 	Training Loss: 0.127767 	Validation Loss: 0.036307
# Epoch: 211 	Training Loss: 0.122402 	Validation Loss: 0.043377
# Epoch: 212 	Training Loss: 0.126052 	Validation Loss: 0.038255
# Epoch: 213 	Training Loss: 0.122583 	Validation Loss: 0.035737
# Validation loss decreased (0.036304 --> 0.035737).  Saving model ...
# Epoch: 214 	Training Loss: 0.120360 	Validation Loss: 0.037354
# Epoch: 215 	Training Loss: 0.120065 	Validation Loss: 0.045663
# Epoch: 216 	Training Loss: 0.122263 	Validation Loss: 0.038028
# Epoch: 217 	Training Loss: 0.117416 	Validation Loss: 0.039980
# Epoch: 218 	Training Loss: 0.112952 	Validation Loss: 0.039668
# Epoch: 219 	Training Loss: 0.113059 	Validation Loss: 0.039951
# Epoch: 220 	Training Loss: 0.114877 	Validation Loss: 0.039232
# Epoch: 221 	Training Loss: 0.108954 	Validation Loss: 0.037877
# Epoch: 222 	Training Loss: 0.108983 	Validation Loss: 0.046348
# Epoch: 223 	Training Loss: 0.110696 	Validation Loss: 0.038206
# Epoch: 224 	Training Loss: 0.107337 	Validation Loss: 0.037418
# Epoch: 225 	Training Loss: 0.105217 	Validation Loss: 0.037959
# Epoch: 226 	Training Loss: 0.107277 	Validation Loss: 0.042969
# Epoch: 227 	Training Loss: 0.104069 	Validation Loss: 0.043116
# Epoch: 228 	Training Loss: 0.104261 	Validation Loss: 0.045993
# Epoch: 229 	Training Loss: 0.100298 	Validation Loss: 0.037393
# Epoch: 230 	Training Loss: 0.102090 	Validation Loss: 0.039401
# Epoch: 231 	Training Loss: 0.098528 	Validation Loss: 0.041138
# Epoch: 232 	Training Loss: 0.095262 	Validation Loss: 0.041258
# Epoch: 233 	Training Loss: 0.101149 	Validation Loss: 0.037209
# Epoch: 234 	Training Loss: 0.096212 	Validation Loss: 0.037915
# Epoch: 235 	Training Loss: 0.101239 	Validation Loss: 0.044352
# Epoch: 236 	Training Loss: 0.097067 	Validation Loss: 0.039108
# Epoch: 237 	Training Loss: 0.093976 	Validation Loss: 0.042753
# Epoch: 238 	Training Loss: 0.094110 	Validation Loss: 0.039854
# Epoch: 239 	Training Loss: 0.092046 	Validation Loss: 0.040797
# Epoch: 240 	Training Loss: 0.091394 	Validation Loss: 0.040866
# Epoch: 241 	Training Loss: 0.087131 	Validation Loss: 0.039641
# Epoch: 242 	Training Loss: 0.087615 	Validation Loss: 0.040251
# Epoch: 243 	Training Loss: 0.086973 	Validation Loss: 0.040547
# Epoch: 244 	Training Loss: 0.089368 	Validation Loss: 0.042092
# Epoch: 245 	Training Loss: 0.086087 	Validation Loss: 0.038888
# Epoch: 246 	Training Loss: 0.081536 	Validation Loss: 0.041011
# Epoch: 247 	Training Loss: 0.079876 	Validation Loss: 0.042283
# Epoch: 248 	Training Loss: 0.082310 	Validation Loss: 0.040535
# Epoch: 249 	Training Loss: 0.082313 	Validation Loss: 0.040599
# Epoch: 250 	Training Loss: 0.081591 	Validation Loss: 0.038786
# Epoch: 251 	Training Loss: 0.080286 	Validation Loss: 0.038643
# Epoch: 252 	Training Loss: 0.073287 	Validation Loss: 0.039649
# Epoch: 253 	Training Loss: 0.077453 	Validation Loss: 0.044079
# Epoch: 254 	Training Loss: 0.079637 	Validation Loss: 0.038850
# Epoch: 255 	Training Loss: 0.077614 	Validation Loss: 0.042540
# Epoch: 256 	Training Loss: 0.074227 	Validation Loss: 0.052981
# Epoch: 257 	Training Loss: 0.072290 	Validation Loss: 0.043913
# Epoch: 258 	Training Loss: 0.072419 	Validation Loss: 0.043506
# Epoch: 259 	Training Loss: 0.074819 	Validation Loss: 0.046446
# Epoch: 260 	Training Loss: 0.069093 	Validation Loss: 0.041543
# Epoch: 261 	Training Loss: 0.064876 	Validation Loss: 0.047279
# Epoch: 262 	Training Loss: 0.068431 	Validation Loss: 0.048177
# Epoch: 263 	Training Loss: 0.068861 	Validation Loss: 0.042944
# Epoch: 264 	Training Loss: 0.069432 	Validation Loss: 0.043860
# Epoch: 265 	Training Loss: 0.062696 	Validation Loss: 0.044817
# Epoch: 266 	Training Loss: 0.059500 	Validation Loss: 0.046117
# Epoch: 267 	Training Loss: 0.068179 	Validation Loss: 0.043165
# Epoch: 268 	Training Loss: 0.067397 	Validation Loss: 0.042503
# Epoch: 269 	Training Loss: 0.063348 	Validation Loss: 0.045053
# Epoch: 270 	Training Loss: 0.063279 	Validation Loss: 0.044263
# Epoch: 271 	Training Loss: 0.062459 	Validation Loss: 0.048020
# Epoch: 272 	Training Loss: 0.062466 	Validation Loss: 0.048191
# Epoch: 273 	Training Loss: 0.055792 	Validation Loss: 0.044679
# Epoch: 274 	Training Loss: 0.061396 	Validation Loss: 0.044890
# Epoch: 275 	Training Loss: 0.057964 	Validation Loss: 0.049920
# Epoch: 276 	Training Loss: 0.058143 	Validation Loss: 0.049741
# Epoch: 277 	Training Loss: 0.053430 	Validation Loss: 0.042256
# Epoch: 278 	Training Loss: 0.059473 	Validation Loss: 0.046072
# Epoch: 279 	Training Loss: 0.055953 	Validation Loss: 0.045484
# Epoch: 280 	Training Loss: 0.062168 	Validation Loss: 0.044112
# Epoch: 281 	Training Loss: 0.052411 	Validation Loss: 0.043963
# Epoch: 282 	Training Loss: 0.053340 	Validation Loss: 0.049536
# Epoch: 283 	Training Loss: 0.051216 	Validation Loss: 0.050612
# Epoch: 284 	Training Loss: 0.046516 	Validation Loss: 0.049029
# Epoch: 285 	Training Loss: 0.055396 	Validation Loss: 0.047518
# Epoch: 286 	Training Loss: 0.050086 	Validation Loss: 0.047982
# Epoch: 287 	Training Loss: 0.048359 	Validation Loss: 0.054591
# Epoch: 288 	Training Loss: 0.055530 	Validation Loss: 0.047254
# Epoch: 289 	Training Loss: 0.046006 	Validation Loss: 0.049928
# Epoch: 290 	Training Loss: 0.048602 	Validation Loss: 0.045880
# Epoch: 291 	Training Loss: 0.047686 	Validation Loss: 0.052833
# Epoch: 292 	Training Loss: 0.050997 	Validation Loss: 0.049770
# Epoch: 293 	Training Loss: 0.045304 	Validation Loss: 0.049990
# Epoch: 294 	Training Loss: 0.043356 	Validation Loss: 0.049634
# Epoch: 295 	Training Loss: 0.045645 	Validation Loss: 0.049805
# Epoch: 296 	Training Loss: 0.045565 	Validation Loss: 0.050097
# Epoch: 297 	Training Loss: 0.044115 	Validation Loss: 0.052491
# Epoch: 298 	Training Loss: 0.047309 	Validation Loss: 0.053272
# Epoch: 299 	Training Loss: 0.047223 	Validation Loss: 0.050537
# Epoch: 300 	Training Loss: 0.048814 	Validation Loss: 0.046870

# %% [markdown]
# ###  Load the Model with the Lowest Validation Loss

# %%
model.load_state_dict(torch.load('model_cifar.pt'))

# %% [markdown]
# ---
# ## Test the Trained Network
#
# Testing trained model on previously unseen data! The model with the lowest validation loss is selected.

# %%
# track test loss
test_loss = 0.0
class_correct = list(0. for i in range(2))
class_total = list(0. for i in range(2))

model.eval()
# iterate over test data
for data, target in test_loader:
    # move tensors to GPU if CUDA is available
    if train_on_gpu:
        data, target = data.cuda(), target.cuda()
    # forward pass: compute predicted outputs by passing inputs to the model
    output = model(data)
    # calculate the batch loss
    loss = criterion(output, target)
    # update test loss 
    test_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)    
    # compare predictions to true label
    correct_tensor = pred.eq(target.data.view_as(pred))
    correct = np.squeeze(correct_tensor.numpy()) if not train_on_gpu else np.squeeze(correct_tensor.cpu().numpy())
    # calculate test accuracy for each object class
    for i in range(batch_size):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

# average test loss
test_loss = test_loss/len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(2):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.035977
#
# Test Accuracy of  DPN-: 88% (1698/1914)
# Test Accuracy of  DPN+: 90% (1650/1826)
#
# Test Accuracy (Overall): 89% (3348/3740)

# %% [markdown]
# ### Visualize Sample Test Results

# %%
# obtain one batch of test images
dataiter = iter(test_loader)
images, labels = dataiter.next()
images.numpy()

# move model inputs to cuda, if GPU available
if train_on_gpu:
    images = images.cuda()

# get sample outputs
output = model(images)
# convert output probabilities to predicted class
_, preds_tensor = torch.max(output, 1)
preds = np.squeeze(preds_tensor.numpy()) if not train_on_gpu else np.squeeze(preds_tensor.cpu().numpy())

# plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])
    ax.set_title("{} ({})".format(classes[preds[idx]], classes[labels[idx]]),
                 color=("green" if preds[idx]==labels[idx].item() else "red"))
